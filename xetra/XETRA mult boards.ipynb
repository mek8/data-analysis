# %%
from plot_func_mult import plot_prices_mult

# %%
plot_prices_mult('dai21082020.csv', 2020, 8, 21, 'dai21082020_chix_m.csv', 'dai21082020_bate_m.csv', 'dai21082020_bxtr_m.csv')
# Out:
# Кол-во записей Quik:
# price    1745
# dtype: int64
# Кол-во записей DxFeed CHIX:
# Price    628
# dtype: int64
# Кол-во записей DxFeed BATE:
# Price    335
# dtype: int64
# Кол-во записей DxFeed BXTR:
# Price    120
# dtype: int64

# %%
plot_prices_mult('dai21082020.csv', 2020, 8, 21, 'dai21082020_chix_a.csv', 'dai21082020_bate_a.csv', 'dai21082020_bxtr_a.csv')
# Out:
# Кол-во записей Quik:
# price    769
# dtype: int64
# Кол-во записей DxFeed CHIX:
# Price    432
# dtype: int64
# Кол-во записей DxFeed BATE:
# Price    248
# dtype: int64
# Кол-во записей DxFeed BXTR:
# Price    63
# dtype: int64

# %%
plot_prices_mult('sie21082020.csv', 2020, 8, 21, 'sie21082020_chix_m.csv', 'sie21082020_bate_m.csv', 'sie21082020_bxtr_m.csv')
# Out:
# Кол-во записей Quik:
# price    984
# dtype: int64
# Кол-во записей DxFeed CHIX:
# Price    491
# dtype: int64
# Кол-во записей DxFeed BATE:
# Price    289
# dtype: int64
# Кол-во записей DxFeed BXTR:
# Price    188
# dtype: int64

# %%
plot_prices_mult('sie21082020.csv', 2020, 8, 21, 'sie21082020_chix_e.csv', 'sie21082020_bate_e.csv', 'sie21082020_bxtr_e.csv')
# Out:
# Кол-во записей Quik:
# price    811
# dtype: int64
# Кол-во записей DxFeed CHIX:
# Price    871
# dtype: int64
# Кол-во записей DxFeed BATE:
# Price    344
# dtype: int64
# Кол-во записей DxFeed BXTR:
# Price    398
# dtype: int64
