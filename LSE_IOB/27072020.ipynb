# %%
from plot_func import plot_prices

# %%
plot_prices('mnod27072020.csv', 'mnod27072020_dx_m.csv', 2020, 7, 27)
# Out:
# Кол-во записей Quik:
# price    585
# dtype: int64
# Кол-во записей DxFeed:
# Price    147
# dtype: int64

# %%
plot_prices('mnod27072020.csv', 'mnod27072020_dx_a.csv', 2020, 7, 27)
# Out:
# Кол-во записей Quik:
# price    499
# dtype: int64
# Кол-во записей DxFeed:
# Price    193
# dtype: int64

# %%
plot_prices('mnod27072020.csv', 'mnod27072020_dx_e.csv', 2020, 7, 27)
# Out:
# Кол-во записей Quik:
# price    530
# dtype: int64
# Кол-во записей DxFeed:
# Price    276
# dtype: int64

# %%
plot_prices('lkod27072020.csv', 'lkod27072020_dx_m.csv', 2020, 7, 27)
# Out:
# Кол-во записей Quik:
# price    199
# dtype: int64
# Кол-во записей DxFeed:
# Price    92
# dtype: int64

# %%
plot_prices('lkod27072020.csv', 'lkod27072020_dx_a.csv', 2020, 7, 27)
# Out:
# Кол-во записей Quik:
# price    106
# dtype: int64
# Кол-во записей DxFeed:
# Price    87
# dtype: int64

# %%
plot_prices('lkod27072020.csv', 'lkod27072020_dx_e.csv', 2020, 7, 27)
# Out:
# Кол-во записей Quik:
# price    634
# dtype: int64
# Кол-во записей DxFeed:
# Price    201
# dtype: int64

# %%
plot_prices('sber27072020.csv', 'sber27072020_dx_m.csv', 2020, 7, 27)
# Out:
# Кол-во записей Quik:
# price    625
# dtype: int64
# Кол-во записей DxFeed:
# Price    226
# dtype: int64

# %%
plot_prices('sber27072020.csv', 'sber27072020_dx_a.csv', 2020, 7, 27)
# Out:
# Кол-во записей Quik:
# price    444
# dtype: int64
# Кол-во записей DxFeed:
# Price    113
# dtype: int64

# %%
plot_prices('sber27072020.csv', 'sber27072020_dx_e.csv', 2020, 7, 27)
# Out:
# Кол-во записей Quik:
# price    315
# dtype: int64
# Кол-во записей DxFeed:
# Price    275
# dtype: int64
