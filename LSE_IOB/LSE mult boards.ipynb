# %%
from plot_func_mult import plot_prices_mult

# %%
plot_prices_mult('lkod27072020.csv', 2020, 7, 27, 'lkod27072020_dx_m.csv', 'lkod27072020_bate_m.csv', 'lkod27072020_bxtr_m.csv')
# Out:
# Кол-во записей Quik:
# price    198
# dtype: int64
# Кол-во записей DxFeed CHIX:
# Price    92
# dtype: int64
# Кол-во записей DxFeed BATE:
# Price    51
# dtype: int64
# Кол-во записей DxFeed BXTR:
# Price    38
# dtype: int64

# %%
plot_prices_mult('lkod27072020.csv', 2020, 7, 27, 'lkod27072020_dx_a.csv', 'lkod27072020_bate_a.csv', 'lkod27072020_bxtr_a.csv')
# Out:
# Кол-во записей Quik:
# price    106
# dtype: int64
# Кол-во записей DxFeed CHIX:
# Price    87
# dtype: int64
# Кол-во записей DxFeed BATE:
# Price    26
# dtype: int64
# Кол-во записей DxFeed BXTR:
# Price    28
# dtype: int64

# %%
plot_prices_mult('mnod27072020.csv', 2020, 7, 27, 'mnod27072020_dx_m.csv', 'mnod27072020_bate_m.csv', 'mnod27072020_bxtr_m.csv')
# Out:
# Кол-во записей Quik:
# price    582
# dtype: int64
# Кол-во записей DxFeed CHIX:
# Price    147
# dtype: int64
# Кол-во записей DxFeed BATE:
# Price    23
# dtype: int64
# Кол-во записей DxFeed BXTR:
# Price    21
# dtype: int64

# %%
plot_prices_mult('mnod27072020.csv', 2020, 7, 27, 'mnod27072020_dx_e.csv', 'mnod27072020_bate_e.csv', 'mnod27072020_bxtr_e.csv')
# Out:
# Кол-во записей Quik:
# price    525
# dtype: int64
# Кол-во записей DxFeed CHIX:
# Price    276
# dtype: int64
# Кол-во записей DxFeed BATE:
# Price    49
# dtype: int64
# Кол-во записей DxFeed BXTR:
# Price    32
# dtype: int64

# %%
plot_prices_mult('mnod27072020.csv', 2020, 7, 27, 'mnod27072020_dx_e.csv', 'mnod27072020_bate_e.csv', 'mnod27072020_bxtr_e_2.csv')
# Out:
# Кол-во записей Quik:
# price    525
# dtype: int64
# Кол-во записей DxFeed CHIX:
# Price    276
# dtype: int64
# Кол-во записей DxFeed BATE:
# Price    49
# dtype: int64
# Кол-во записей DxFeed BXTR:
# Price    30
# dtype: int64
