# %%
from plot_func import plot_prices

# %%
plot_prices('mnod29072020.csv', 'mnod29072020_dx_m.csv', 2020, 7, 29)
# Out:
# Кол-во записей Quik:
# price    264
# dtype: int64
# Кол-во записей DxFeed:
# Price    93
# dtype: int64

# %%
plot_prices('mnod29072020.csv', 'mnod29072020_dx_a.csv', 2020, 7, 29)
# Out:
# Кол-во записей Quik:
# price    301
# dtype: int64
# Кол-во записей DxFeed:
# Price    81
# dtype: int64

# %%
plot_prices('mnod29072020.csv', 'mnod29072020_dx_e.csv', 2020, 7, 29)
# Out:
# Кол-во записей Quik:
# price    552
# dtype: int64
# Кол-во записей DxFeed:
# Price    195
# dtype: int64

# %%
plot_prices('lkod29072020.csv', 'lkod29072020_dx_m.csv', 2020, 7, 29)
# Out:
# Кол-во записей Quik:
# price    2041
# dtype: int64
# Кол-во записей DxFeed:
# Price    220
# dtype: int64

# %%
plot_prices('lkod29072020.csv', 'lkod29072020_dx_a.csv', 2020, 7, 29)
# Out:
# Кол-во записей Quik:
# price    549
# dtype: int64
# Кол-во записей DxFeed:
# Price    79
# dtype: int64

# %%
plot_prices('lkod29072020.csv', 'lkod29072020_dx_e.csv', 2020, 7, 29)
# Out:
# Кол-во записей Quik:
# price    1243
# dtype: int64
# Кол-во записей DxFeed:
# Price    354
# dtype: int64

# %%
plot_prices('sber29072020.csv', 'sber29072020_dx_m.csv', 2020, 7, 29)
# Out:
# Кол-во записей Quik:
# price    1065
# dtype: int64
# Кол-во записей DxFeed:
# Price    376
# dtype: int64

# %%
plot_prices('sber29072020.csv', 'sber29072020_dx_a.csv', 2020, 7, 29)
# Out:
# Кол-во записей Quik:
# price    505
# dtype: int64
# Кол-во записей DxFeed:
# Price    160
# dtype: int64

# %%
plot_prices('sber29072020.csv', 'sber29072020_dx_e.csv', 2020, 7, 29)
# Out:
# Кол-во записей Quik:
# price    714
# dtype: int64
# Кол-во записей DxFeed:
# Price    245
# dtype: int64
